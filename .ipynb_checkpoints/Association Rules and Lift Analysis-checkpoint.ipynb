# %% [markdown]
# # Association Rules and Lift Analysis

# %% [markdown]
# ## Part I: Research Question

# %% [markdown]
# Can we identify key associations of customer purchases through market basket analysis?
#
# We will answer this using market basket analysis.
#
# The goal is to perform a market basket analysis to analyze customer data to identify key associations of your customer purchases, ultimately allowing better business and strategic decision-making.

# %% [markdown]
# ## Part II: Method Justification

# %% [markdown]
# Market Basket Analysis (MBA) is a data mining technique that allows us to analyze what customers buy, how & why they buy it, and what they buy together.
#
# The underlying assumption in market basket analysis is that joint occurrence of two or more products in most baskets imply that these products are complements in purchase, therefore, purchase of one will lead to purchase of others.
#
# One transaction in the dataset is:
# Apple Lightning to Digital AV Adapter,TP-Link AC1750 Smart WiFi Router,Apple Pencil
# We can already make an assumption based on the first purchase that they have an apple device, so seeing the Apple Pencil being purchased at the end correlates with the assumption thay they have an apple device and multiple apple products would be purchased together.

# %% [markdown]
# ## Part III: Data Preparation

# %%
# Importing packages to be used
import numpy as np
# numpy for data analysis functionality
import pandas as pd
# pandas for dataframes
from mlxtend.frequent_patterns import apriori
from apyori import apriori
# Apriori Algorithm
from mlxtend.frequent_patterns import association_rules
# Import ElbowVisualizer
from yellowbrick.cluster import KElbowVisualizer
import matplotlib.pyplot as plt
# %matplotlib inline
# matplotlib for plotting
import seaborn as sns
# seaborn for extra plotting functionality

# %%
# Importing dataset
df = pd.read_csv('Churn Data\churn_clean2.csv')

# %%
# Showing data
df
# Out:
#                                       Item01  \
# 0                                        NaN
# 1               Logitech M510 Wireless mouse
# 2                                        NaN
# 3      Apple Lightning to Digital AV Adapter
# 4                                        NaN
# ...                                      ...
# 14997         Falcon Dust Off Compressed Gas
# 14998                                    NaN
# 14999                            HP 63XL Ink
# 15000                                    NaN
# 15001                           Apple Pencil
#
#                                  Item02                 Item03  \
# 0                                   NaN                    NaN
# 1                             HP 63 Ink              HP 65 ink
# 2                                   NaN                    NaN
# 3      TP-Link AC1750 Smart WiFi Router           Apple Pencil
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 14997                               NaN                    NaN
# 14998                               NaN                    NaN
# 14999         Apple USB-C Charger cable                    NaN
# 15000                               NaN                    NaN
# 15001          SanDisk Ultra 128GB card  RUNMUS Gaming Headset
#
#                              Item04                     Item05        Item06  \
# 0                               NaN                        NaN           NaN
# 1        nonda USB C to USB Adapter  10ft iPHone Charger Cable  HP 902XL ink
# 2                               NaN                        NaN           NaN
# 3                               NaN                        NaN           NaN
# 4                               NaN                        NaN           NaN
# ...                             ...                        ...           ...
# 14997                           NaN                        NaN           NaN
# 14998                           NaN                        NaN           NaN
# 14999                           NaN                        NaN           NaN
# 15000                           NaN                        NaN           NaN
# 15001  TopMate C5 Laptop Cooler pad                        NaN           NaN
#
#                              Item07                               Item08  \
# 0                               NaN                                  NaN
# 1      Creative Pebble 2.0 Speakers  Cleaning Gel Universal Dust Cleaner
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 14997                           NaN                                  NaN
# 14998                           NaN                                  NaN
# 14999                           NaN                                  NaN
# 15000                           NaN                                  NaN
# 15001                           NaN                                  NaN
#
#                               Item09                                   Item10  \
# 0                                NaN                                      NaN
# 1      Micro Center 32GB Memory card  YUNSONG 3pack 6ft Nylon Lightning Cable
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
# ...                              ...                                      ...
# 14997                            NaN                                      NaN
# 14998                            NaN                                      NaN
# 14999                            NaN                                      NaN
# 15000                            NaN                                      NaN
# 15001                            NaN                                      NaN
#
#                              Item11                     Item12  \
# 0                               NaN                        NaN
# 1      TopMate C5 Laptop Cooler pad  Apple USB-C Charger cable
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 14997                           NaN                        NaN
# 14998                           NaN                        NaN
# 14999                           NaN                        NaN
# 15000                           NaN                        NaN
# 15001                           NaN                        NaN
#
#                              Item13                       Item14  \
# 0                               NaN                          NaN
# 1      HyperX Cloud Stinger Headset  TONOR USB Gaming Microphone
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 14997                           NaN                          NaN
# 14998                           NaN                          NaN
# 14999                           NaN                          NaN
# 15000                           NaN                          NaN
# 15001                           NaN                          NaN
#
#                                Item15                          Item16  \
# 0                                 NaN                             NaN
# 1      Dust-Off Compressed Gas 2 pack  3A USB Type C Cable 3 pack 6FT
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 14997                             NaN                             NaN
# 14998                             NaN                             NaN
# 14999                             NaN                             NaN
# 15000                             NaN                             NaN
# 15001                             NaN                             NaN
#
#                       Item17                    Item18  \
# 0                        NaN                       NaN
# 1      HOVAMP iPhone charger  SanDisk Ultra 128GB card
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 14997                    NaN                       NaN
# 14998                    NaN                       NaN
# 14999                    NaN                       NaN
# 15000                    NaN                       NaN
# 15001                    NaN                       NaN
#
#                                      Item19  \
# 0                                       NaN
# 1      FEEL2NICE 5 pack 10ft Lighning cable
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 14997                                   NaN
# 14998                                   NaN
# 14999                                   NaN
# 15000                                   NaN
# 15001                                   NaN
#
#                                     Item20
# 0                                      NaN
# 1      FEIYOLD Blue light Blocking Glasses
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 14997                                  NaN
# 14998                                  NaN
# 14999                                  NaN
# 15000                                  NaN
# 15001                                  NaN
#
# [15002 rows x 20 columns]

# %%
# Checking for null values
df.isna().any()
# Out:
# Item01    True
# Item02    True
# Item03    True
# Item04    True
# Item05    True
# Item06    True
# Item07    True
# Item08    True
# Item09    True
# Item10    True
# Item11    True
# Item12    True
# Item13    True
# Item14    True
# Item15    True
# Item16    True
# Item17    True
# Item18    True
# Item19    True
# Item20    True
# dtype: bool

# %% [markdown]
# True, meaning each column has null values

# %%
# Converting null to 0
newdf = df.fillna(0)

# %%
# Checking for null values
newdf.isna().any()
# Out:
# Item01    False
# Item02    False
# Item03    False
# Item04    False
# Item05    False
# Item06    False
# Item07    False
# Item08    False
# Item09    False
# Item10    False
# Item11    False
# Item12    False
# Item13    False
# Item14    False
# Item15    False
# Item16    False
# Item17    False
# Item18    False
# Item19    False
# Item20    False
# dtype: bool

# %% [markdown]
# Now false, meaning there are no longer any nulls

# %%
# export file to csv
newdf.to_csv('cleaned_data3.csv', index = False)

# %% [markdown]
# ## Part IV: Analysis

# %%
# Converting dataframe into lists
transactions = []
for i in range(0, 15001):
    transactions.append([str(newdf.values[i,j]) for j in range(0, 20)])

# %%
# Running apriori algorithm
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
# Turning results from apriori into a list
result = list(rules)
result
# Out:
# [RelationRecord(items=frozenset({'Dust-Off Compressed Gas 2 pack', '10ft iPHone Charger Cable 2 Pack'}), support=0.011532564495700287, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.45646437994722955, lift=3.829654453908496)]),
#  RelationRecord(items=frozenset({'10ft iPHone Charger Cable 2 Pack', 'Screen Mom Screen Cleaner kit'}), support=0.0075994933671088595, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.3007915567282322, lift=4.642154467572234)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', '10ft iPHone Charger Cable 2 Pack'}), support=0.007132857809479368, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2823218997361478, lift=3.242810733493073)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'Dust-Off Compressed Gas 2 pack'}), support=0.008532764482367842, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4012539184952978, lift=3.366448563393715)]),
#  RelationRecord(items=frozenset({'HP 61 ink', '3A USB Type C Cable 3 pack 6FT'}), support=0.005332977801479902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'HP 61 ink'}), confidence=0.2507836990595611, lift=3.06103032513627)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', '3A USB Type C Cable 3 pack 6FT'}), support=0.004466368908739417, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.21003134796238243, lift=4.275007124536905)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'Screen Mom Screen Cleaner kit'}), support=0.0048663422438504095, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2288401253918495, lift=3.531718848768657)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'VIVO Dual LCD Monitor Desk mount'}), support=0.006732884474368375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3166144200626959, lift=3.6367020791428035)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'Anker 2-in-1 USB Card Reader'}), support=0.003999733351109926, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'FEIYOLD Blue light Blocking Glasses'}), confidence=0.27149321266968324, lift=8.244270613882426)]),
#  RelationRecord(items=frozenset({'Anker 2-in-1 USB Card Reader', 'Screen Mom Screen Cleaner kit'}), support=0.004933004466368909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.33484162895927605, lift=5.167653576150308)]),
#  RelationRecord(items=frozenset({'Anker 2-in-1 USB Card Reader', 'VIVO Dual LCD Monitor Desk mount'}), support=0.004399706686220918, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2986425339366516, lift=3.4302730869706815)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Anker USB C to HDMI Adapter'}), support=0.00806612892473835, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.2358674463937622, lift=4.948597990703254)]),
#  RelationRecord(items=frozenset({'Anker USB C to HDMI Adapter', 'Screen Mom Screen Cleaner kit'}), support=0.006999533364442371, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20467836257309943, lift=3.158827280822083)]),
#  RelationRecord(items=frozenset({'Anker USB C to HDMI Adapter', 'VIVO Dual LCD Monitor Desk mount'}), support=0.010465968935404307, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.30604288499025345, lift=3.5152751284370534)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Apple Pencil'}), support=0.014399040063995734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3302752293577982, lift=3.6781430702274167)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Apple USB-C Charger cable'}), support=0.008732751149923338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.2003058103975535, lift=3.032076147097578)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Screen Mom Screen Cleaner kit'}), support=0.008932737817478834, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20489296636085624, lift=3.162139288455972)]),
#  RelationRecord(items=frozenset({'Apple Lightning to USB cable', 'Dust-Off Compressed Gas 2 pack'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to USB cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4700854700854701, lift=3.943932962389338)]),
#  RelationRecord(items=frozenset({'Cat8 Ethernet Cable', 'Apple Pencil'}), support=0.009732684487700819, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3113006396588486, lift=3.466830657403406)]),
#  RelationRecord(items=frozenset({'HP 63 Ink', 'Apple Pencil'}), support=0.0032664489034064394, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 63 Ink'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3202614379084967, lift=3.5666234818599545)]),
#  RelationRecord(items=frozenset({'Apple USB-C Charger cable', 'Cleaning Gel Universal Dust Cleaner'}), support=0.0031997866808879407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cleaning Gel Universal Dust Cleaner'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.200836820083682, lift=3.0401141655654023)]),
#  RelationRecord(items=frozenset({'Apple USB-C Charger cable', 'Logitech MK345 Wireless combo'}), support=0.003333111125924938, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech MK345 Wireless combo'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.20576131687242796, lift=3.1146574312848556)]),
#  RelationRecord(items=frozenset({'Apple USB-C Charger cable', 'SanDisk 32GB Ultra SDHC card'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 32GB Ultra SDHC card'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.24336283185840707, lift=3.6838404043470883)]),
#  RelationRecord(items=frozenset({'YUNSONG 3pack 6ft Nylon Lightning Cable', 'Apple USB-C Charger cable'}), support=0.003133124458369442, ordered_statistics=[OrderedStatistic(items_base=frozenset({'YUNSONG 3pack 6ft Nylon Lightning Cable'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.20614035087719298, lift=3.1203949581319597)]),
#  RelationRecord(items=frozenset({'iPhone Charger Cable Anker 6ft', 'Apple USB-C Charger cable'}), support=0.0032664489034064394, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone Charger Cable Anker 6ft'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.2538860103626943, lift=3.8431322315345886)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'AutoFocus 1080p Webcam'}), support=0.003133124458369442, ordered_statistics=[OrderedStatistic(items_base=frozenset({'AutoFocus 1080p Webcam'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.4433962264150943, lift=5.092945476610129)]),
#  RelationRecord(items=frozenset({'Brother Genuine High Yield Toner Cartridge', 'Dust-Off Compressed Gas 2 pack'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brother Genuine High Yield Toner Cartridge'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4172661870503597, lift=3.5007886308402942)]),
#  RelationRecord(items=frozenset({'Cat8 Ethernet Cable', 'VIVO Dual LCD Monitor Desk mount'}), support=0.008266115592293847, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.26439232409381663, lift=3.036867728737629)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'Dust-Off Compressed Gas 2 pack'}), support=0.013799080061329246, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4190283400809717, lift=3.5155727793929845)]),
#  RelationRecord(items=frozenset({'Dust-Off Compressed Gas 2 pack', 'Falcon Dust Off Compressed Gas'}), support=0.01139924005066329, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Falcon Dust Off Compressed Gas'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.38, lift=3.188131991051454)]),
#  RelationRecord(items=frozenset({'HP 62XL ink', 'Dust-Off Compressed Gas 2 pack'}), support=0.0041330577961469234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 62XL ink'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3668639053254438, lift=3.07792250771084)]),
#  RelationRecord(items=frozenset({'HP 63 Ink', 'Dust-Off Compressed Gas 2 pack'}), support=0.0037997466835544298, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 63 Ink'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3725490196078431, lift=3.1256195990700526)]),
#  RelationRecord(items=frozenset({'Jelly Comb 2.4G Slim Wireless mouse', 'Dust-Off Compressed Gas 2 pack'}), support=0.004399706686220918, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jelly Comb 2.4G Slim Wireless mouse'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3952095808383233, lift=3.3157376522123534)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Dust-Off Compressed Gas 2 pack'}), support=0.01786547563495767, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3748251748251748, lift=3.144716133977879)]),
#  RelationRecord(items=frozenset({'Dust-Off Compressed Gas 2 pack', 'Premium Nylon USB Cable'}), support=0.010065995600293315, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.39425587467362927, lift=3.3077362281762372)]),
#  RelationRecord(items=frozenset({'SanDisk Extreme Pro 128GB card', 'Dust-Off Compressed Gas 2 pack'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Extreme Pro 128GB card'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4113475177304965, lift=3.4511320545163184)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'Dust-Off Compressed Gas 2 pack'}), support=0.020465302313179123, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4165535956580733, lift=3.4948101165921464)]),
#  RelationRecord(items=frozenset({'Dust-Off Compressed Gas 2 pack', 'Screen Mom Screen Cleaner kit'}), support=0.023998400106659556, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dust-Off Compressed Gas 2 pack'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20134228187919462, lift=3.107341121882509), OrderedStatistic(items_base=frozenset({'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.37037037037037035, lift=3.107341121882509)]),
#  RelationRecord(items=frozenset({'TP-Link AC1750 Smart WiFi Router', 'Dust-Off Compressed Gas 2 pack'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'TP-Link AC1750 Smart WiFi Router'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.36942675159235666, lift=3.099424329215292)]),
#  RelationRecord(items=frozenset({'VicTsing Wireless mouse', 'Dust-Off Compressed Gas 2 pack'}), support=0.005466302246516899, ordered_statistics=[OrderedStatistic(items_base=frozenset({'VicTsing Wireless mouse'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3886255924170616, lift=3.2604991677004147)]),
#  RelationRecord(items=frozenset({'iPhone Charger Cable Anker 6ft', 'Dust-Off Compressed Gas 2 pack'}), support=0.005132991133924405, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone Charger Cable Anker 6ft'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3989637305699482, lift=3.3472342965770654)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'FEIYOLD Blue light Blocking Glasses'}), support=0.008199453369775348, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'HP 61 ink'}), confidence=0.24898785425101214, lift=3.03911049765617)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'FEIYOLD Blue light Blocking Glasses'}), support=0.00706619558696087, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.21457489878542513, lift=4.367487186811618)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'Screen Mom Screen Cleaner kit'}), support=0.008532764482367842, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2591093117408907, lift=3.998867063194549)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'VIVO Dual LCD Monitor Desk mount'}), support=0.011465902273181788, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3481781376518219, lift=3.9992498031508266)]),
#  RelationRecord(items=frozenset({'Screen Mom Screen Cleaner kit', 'Falcon Dust Off Compressed Gas'}), support=0.007399506699553363, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Falcon Dust Off Compressed Gas'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.24666666666666667, lift=3.8068381344307274)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Falcon Dust Off Compressed Gas'}), support=0.00859942670488634, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Falcon Dust Off Compressed Gas'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2866666666666666, lift=3.2927156712608467)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'HP 952 ink'}), support=0.003066462235850943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 952 ink'}), items_add=frozenset({'HP 61 ink'}), confidence=0.2658959537572254, lift=3.24548836640532)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'Logitech M510 Wireless mouse'}), support=0.008999400039997333, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech M510 Wireless mouse'}), items_add=frozenset({'HP 61 ink'}), confidence=0.251865671641791, lift=3.0742367292908925)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'Premium Nylon USB Cable'}), support=0.006799546696886874, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable'}), items_add=frozenset({'HP 61 ink'}), confidence=0.26631853785900783, lift=3.250646368122845)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'SanDisk 32GB Ultra SDHC card'}), support=0.0041330577961469234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 32GB Ultra SDHC card'}), items_add=frozenset({'HP 61 ink'}), confidence=0.2743362831858407, lift=3.3485098324416565)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'Screen Mom Screen Cleaner kit'}), support=0.016065595626958203, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'HP 61 ink'}), confidence=0.24794238683127573, lift=3.026349670346596)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'USB Type C Cable'}), support=0.005799613359109393, ordered_statistics=[OrderedStatistic(items_base=frozenset({'USB Type C Cable'}), items_add=frozenset({'HP 61 ink'}), confidence=0.24786324786324787, lift=3.025383711307226)]),
#  RelationRecord(items=frozenset({'HP 62XL Tri-Color ink', 'Screen Mom Screen Cleaner kit'}), support=0.00593293780414639, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 62XL Tri-Color ink'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20273348519362186, lift=3.1288117401126767)]),
#  RelationRecord(items=frozenset({'HP 62XL ink', 'VIVO Dual LCD Monitor Desk mount'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 62XL ink'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3431952662721893, lift=3.9420154589196876)]),
#  RelationRecord(items=frozenset({'Screen Mom Screen Cleaner kit', 'HP 65 ink'}), support=0.003733084461035931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 65 ink'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.224, lift=3.4570205761316872)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Jelly Comb 2.4G Slim Wireless mouse'}), support=0.003399773348443437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jelly Comb 2.4G Slim Wireless mouse'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3053892215568862, lift=3.507767008097128)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Logitech M510 Wireless mouse'}), support=0.008332777814812346, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech M510 Wireless mouse'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.2332089552238806, lift=4.892821730508298)]),
#  RelationRecord(items=frozenset({'Logitech M510 Wireless mouse', 'Screen Mom Screen Cleaner kit'}), support=0.008799413372441837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech M510 Wireless mouse'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2462686567164179, lift=3.8006955960936057)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Logitech M510 Wireless mouse'}), support=0.010599293380441304, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech M510 Wireless mouse'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.29664179104477617, lift=3.4072921190372796)]),
#  RelationRecord(items=frozenset({'Logitech MK345 Wireless combo', 'VIVO Dual LCD Monitor Desk mount'}), support=0.00433304446370242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech MK345 Wireless combo'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2674897119341564, lift=3.072444999023185)]),
#  RelationRecord(items=frozenset({'Mpow HC6 USB Headset', 'VIVO Dual LCD Monitor Desk mount'}), support=0.004599693353776415, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mpow HC6 USB Headset'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.34673366834170855, lift=3.9826583145436216)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Screen Mom Screen Cleaner kit'}), support=0.011799213385774282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.24755244755244754, lift=3.820508503841837)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount'}), support=0.013932404506366243, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2923076923076923, lift=3.3575097184591827)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'PS4 Headset'}), support=0.003399773348443437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PS4 Headset'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3422818791946308, lift=3.931524096323627)]),
#  RelationRecord(items=frozenset({'Screen Mom Screen Cleaner kit', 'Premium Nylon USB Cable'}), support=0.005732951136590894, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2245430809399478, lift=3.465402013559832)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Premium Nylon USB Cable'}), support=0.007932804479701353, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.31070496083550914, lift=3.5688247454008213)]),
#  RelationRecord(items=frozenset({'SAMSUNG EVO 32GB card', 'SanDisk Ultra 64GB card'}), support=0.005666288914072395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SAMSUNG EVO 32GB card'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.2162849872773537, lift=4.402294564650723)]),
#  RelationRecord(items=frozenset({'SAMSUNG EVO 32GB card', 'VIVO Dual LCD Monitor Desk mount'}), support=0.008266115592293847, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SAMSUNG EVO 32GB card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3155216284987277, lift=3.6241500376029205)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'SanDisk 128GB Ultra microSDXC card'}), support=0.007999466702219852, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 128GB Ultra microSDXC card'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.3234501347708895, lift=6.583548808274238)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'SanDisk 128GB Ultra microSDXC card'}), support=0.00813279114725685, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 128GB Ultra microSDXC card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3288409703504043, lift=3.777138894507209)]),
#  RelationRecord(items=frozenset({'SanDisk 128GB microSDXC card', 'Screen Mom Screen Cleaner kit'}), support=0.004599693353776415, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 128GB microSDXC card'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2136222910216718, lift=3.2968600695638877)]),
#  RelationRecord(items=frozenset({'SanDisk 32GB Ultra SDHC card', 'Screen Mom Screen Cleaner kit'}), support=0.003066462235850943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 32GB Ultra SDHC card'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20353982300884954, lift=3.1412560544812265)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 128GB card', 'Screen Mom Screen Cleaner kit'}), support=0.007132857809479368, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 128GB card'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2257383966244726, lift=3.4838494730079357)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit'}), support=0.010999266715552297, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.22388059701492538, lift=3.455177814630551)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount'}), support=0.01959869342043864, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3989145183175034, lift=4.582018904502962), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.22511485451761104, lift=4.582018904502962)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'iPhone SE case'}), support=0.0032664489034064394, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone SE case'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.24623115577889448, lift=5.011823022848299)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit'}), support=0.01773215118992067, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2736625514403292, lift=3.1433475759237197), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20367534456355282, lift=3.14334757592372)]),
#  RelationRecord(items=frozenset({'iPhone Charger Cable Anker 6ft', 'Screen Mom Screen Cleaner kit'}), support=0.003533097793480435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone Charger Cable Anker 6ft'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2746113989637306, lift=4.238112752937163)]),
#  RelationRecord(items=frozenset({'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount'}), support=0.012599160055996267, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stylus Pen for iPad'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2650771388499299, lift=3.0447336599447152)]),
#  RelationRecord(items=frozenset({'TP-Link AC1750 Smart WiFi Router', 'VIVO Dual LCD Monitor Desk mount'}), support=0.0031997866808879407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'TP-Link AC1750 Smart WiFi Router'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3057324840764331, lift=3.5117097960417865)]),
#  RelationRecord(items=frozenset({'Vsco 70 pack stickers', 'USB 2.0 Printer cable'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Vsco 70 pack stickers'}), items_add=frozenset({'USB 2.0 Printer cable'}), confidence=0.26960784313725494, lift=3.1547482487534797)]),
#  RelationRecord(items=frozenset({'VicTsing Wireless mouse', 'VIVO Dual LCD Monitor Desk mount'}), support=0.005132991133924405, ordered_statistics=[OrderedStatistic(items_base=frozenset({'VicTsing Wireless mouse'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.36492890995260663, lift=4.191652816385186)]),
#  RelationRecord(items=frozenset({'iPhone SE case', 'VIVO Dual LCD Monitor Desk mount'}), support=0.004933004466368909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone SE case'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3718592964824121, lift=4.27125674313374)]),
#  RelationRecord(items=frozenset({'Dust-Off Compressed Gas 2 pack', '10ft iPHone Charger Cable 2 Pack', '0'}), support=0.011532564495700287, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.45646437994722955, lift=3.8317975173969727), OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.45646437994722955, lift=3.829654453908496)]),
#  RelationRecord(items=frozenset({'Screen Mom Screen Cleaner kit', '10ft iPHone Charger Cable 2 Pack', '0'}), support=0.0075994933671088595, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.3007915567282322, lift=4.642154467572234), OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.3007915567282322, lift=4.642154467572234)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', '10ft iPHone Charger Cable 2 Pack', '0'}), support=0.007132857809479368, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.2823218997361478, lift=3.242810733493073), OrderedStatistic(items_base=frozenset({'10ft iPHone Charger Cable 2 Pack', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2823218997361478, lift=3.242810733493073)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.008466102259849343, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.39811912225705326, lift=3.3420173211964497), OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3993710691823899, lift=3.350651794633686)]),
#  RelationRecord(items=frozenset({'HP 61 ink', '3A USB Type C Cable 3 pack 6FT', '0'}), support=0.005332977801479902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.2507836990595611, lift=3.06103032513627), OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.25157232704402516, lift=3.070656206661856)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', '3A USB Type C Cable 3 pack 6FT', '0'}), support=0.004466368908739417, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.21003134796238243, lift=4.275007124536905), OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.21069182389937105, lift=4.288450543167524)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'Screen Mom Screen Cleaner kit', '0'}), support=0.0048663422438504095, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.2288401253918495, lift=3.531718848768657), OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.22955974842767293, lift=3.5428248828842817)]),
#  RelationRecord(items=frozenset({'3A USB Type C Cable 3 pack 6FT', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.006732884474368375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.3166144200626959, lift=3.6367020791428035), OrderedStatistic(items_base=frozenset({'3A USB Type C Cable 3 pack 6FT', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.31761006289308175, lift=3.648138249203001)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'Anker 2-in-1 USB Card Reader', '0'}), support=0.003999733351109926, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'FEIYOLD Blue light Blocking Glasses', '0'}), confidence=0.27149321266968324, lift=8.260993272328435), OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader', '0'}), items_add=frozenset({'FEIYOLD Blue light Blocking Glasses'}), confidence=0.27149321266968324, lift=8.244270613882426)]),
#  RelationRecord(items=frozenset({'Anker 2-in-1 USB Card Reader', 'Screen Mom Screen Cleaner kit', '0'}), support=0.004933004466368909, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.33484162895927605, lift=5.167653576150308), OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.33484162895927605, lift=5.167653576150308)]),
#  RelationRecord(items=frozenset({'Anker 2-in-1 USB Card Reader', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.004399706686220918, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.2986425339366516, lift=3.4302730869706815), OrderedStatistic(items_base=frozenset({'Anker 2-in-1 USB Card Reader', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2986425339366516, lift=3.4302730869706815)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Anker USB C to HDMI Adapter', '0'}), support=0.00806612892473835, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'Nylon Braided Lightning to USB cable', '0'}), confidence=0.2358674463937622, lift=4.948597990703254), OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter', '0'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.2358674463937622, lift=4.948597990703254)]),
#  RelationRecord(items=frozenset({'Anker USB C to HDMI Adapter', 'Screen Mom Screen Cleaner kit', '0'}), support=0.006999533364442371, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.20467836257309943, lift=3.158827280822083), OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20467836257309943, lift=3.158827280822083)]),
#  RelationRecord(items=frozenset({'Anker USB C to HDMI Adapter', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.010465968935404307, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.30604288499025345, lift=3.5152751284370534), OrderedStatistic(items_base=frozenset({'Anker USB C to HDMI Adapter', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.30604288499025345, lift=3.5152751284370534)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Apple Pencil', '0'}), support=0.014399040063995734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Apple Pencil', '0'}), confidence=0.3302752293577982, lift=3.6781430702274167), OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter', '0'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3302752293577982, lift=3.6781430702274167)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Apple USB-C Charger cable', '0'}), support=0.008732751149923338, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Apple USB-C Charger cable', '0'}), confidence=0.2003058103975535, lift=3.0351388502764647), OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter', '0'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.2003058103975535, lift=3.032076147097578)]),
#  RelationRecord(items=frozenset({'Apple Lightning to Digital AV Adapter', 'Screen Mom Screen Cleaner kit', '0'}), support=0.008932737817478834, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.20489296636085624, lift=3.162139288455972), OrderedStatistic(items_base=frozenset({'Apple Lightning to Digital AV Adapter', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.20489296636085624, lift=3.162139288455972)]),
#  RelationRecord(items=frozenset({'Apple Lightning to USB cable', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple Lightning to USB cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.4700854700854701, lift=3.9461399757986215), OrderedStatistic(items_base=frozenset({'Apple Lightning to USB cable', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4700854700854701, lift=3.943932962389338)]),
#  RelationRecord(items=frozenset({'Cat8 Ethernet Cable', 'Apple Pencil', '0'}), support=0.009732684487700819, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable'}), items_add=frozenset({'Apple Pencil', '0'}), confidence=0.3113006396588486, lift=3.466830657403406), OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable', '0'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3113006396588486, lift=3.466830657403406)]),
#  RelationRecord(items=frozenset({'HP 63 Ink', 'Apple Pencil', '0'}), support=0.0032664489034064394, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 63 Ink'}), items_add=frozenset({'Apple Pencil', '0'}), confidence=0.3202614379084967, lift=3.5666234818599545), OrderedStatistic(items_base=frozenset({'HP 63 Ink', '0'}), items_add=frozenset({'Apple Pencil'}), confidence=0.3223684210526315, lift=3.5900881100300857)]),
#  RelationRecord(items=frozenset({'Apple USB-C Charger cable', 'Logitech MK345 Wireless combo', '0'}), support=0.003333111125924938, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Logitech MK345 Wireless combo'}), items_add=frozenset({'Apple USB-C Charger cable', '0'}), confidence=0.20576131687242796, lift=3.117803549902315), OrderedStatistic(items_base=frozenset({'Logitech MK345 Wireless combo', '0'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.20576131687242796, lift=3.1146574312848556)]),
#  RelationRecord(items=frozenset({'Apple USB-C Charger cable', 'SanDisk 32GB Ultra SDHC card', '0'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk 32GB Ultra SDHC card'}), items_add=frozenset({'Apple USB-C Charger cable', '0'}), confidence=0.24336283185840707, lift=3.68756145526057), OrderedStatistic(items_base=frozenset({'SanDisk 32GB Ultra SDHC card', '0'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.24336283185840707, lift=3.6838404043470883)]),
#  RelationRecord(items=frozenset({'YUNSONG 3pack 6ft Nylon Lightning Cable', 'Apple USB-C Charger cable', '0'}), support=0.003066462235850943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'YUNSONG 3pack 6ft Nylon Lightning Cable'}), items_add=frozenset({'Apple USB-C Charger cable', '0'}), confidence=0.20175438596491227, lift=3.0570884281410597), OrderedStatistic(items_base=frozenset({'YUNSONG 3pack 6ft Nylon Lightning Cable', '0'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.2026431718061674, lift=3.0674573362909356)]),
#  RelationRecord(items=frozenset({'iPhone Charger Cable Anker 6ft', 'Apple USB-C Charger cable', '0'}), support=0.0032664489034064394, ordered_statistics=[OrderedStatistic(items_base=frozenset({'iPhone Charger Cable Anker 6ft'}), items_add=frozenset({'Apple USB-C Charger cable', '0'}), confidence=0.2538860103626943, lift=3.8470141832836138), OrderedStatistic(items_base=frozenset({'iPhone Charger Cable Anker 6ft', '0'}), items_add=frozenset({'Apple USB-C Charger cable'}), confidence=0.2538860103626943, lift=3.8431322315345886)]),
#  RelationRecord(items=frozenset({'AutoFocus 1080p Webcam', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.003133124458369442, ordered_statistics=[OrderedStatistic(items_base=frozenset({'AutoFocus 1080p Webcam'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.4433962264150943, lift=5.092945476610129), OrderedStatistic(items_base=frozenset({'AutoFocus 1080p Webcam', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.4433962264150943, lift=5.092945476610129)]),
#  RelationRecord(items=frozenset({'Brother Genuine High Yield Toner Cartridge', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brother Genuine High Yield Toner Cartridge'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.4172661870503597, lift=3.5027476619711506), OrderedStatistic(items_base=frozenset({'Brother Genuine High Yield Toner Cartridge', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4172661870503597, lift=3.5007886308402942)]),
#  RelationRecord(items=frozenset({'Cat8 Ethernet Cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.008266115592293847, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.26439232409381663, lift=3.036867728737629), OrderedStatistic(items_base=frozenset({'Cat8 Ethernet Cable', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.26439232409381663, lift=3.036867728737629)]),
#  RelationRecord(items=frozenset({'FEIYOLD Blue light Blocking Glasses', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.013732417838810747, ordered_statistics=[OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.417004048582996, lift=3.500547136426146), OrderedStatistic(items_base=frozenset({'FEIYOLD Blue light Blocking Glasses', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4178498985801217, lift=3.5056858661076093)]),
#  RelationRecord(items=frozenset({'Falcon Dust Off Compressed Gas', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.01139924005066329, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Falcon Dust Off Compressed Gas'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.38, lift=3.189916060436486), OrderedStatistic(items_base=frozenset({'Falcon Dust Off Compressed Gas', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.38, lift=3.188131991051454)]),
#  RelationRecord(items=frozenset({'HP 62XL ink', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.0041330577961469234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 62XL ink'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.3668639053254438, lift=3.0796449041896934), OrderedStatistic(items_base=frozenset({'HP 62XL ink', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3668639053254438, lift=3.07792250771084)]),
#  RelationRecord(items=frozenset({'HP 63 Ink', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.003733084461035931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 63 Ink'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.3660130718954248, lift=3.0725025693918675), OrderedStatistic(items_base=frozenset({'HP 63 Ink', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3684210526315789, lift=3.0909866949252325)]),
#  RelationRecord(items=frozenset({'Jelly Comb 2.4G Slim Wireless mouse', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.004399706686220918, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jelly Comb 2.4G Slim Wireless mouse'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.3952095808383233, lift=3.31759312935405), OrderedStatistic(items_base=frozenset({'Jelly Comb 2.4G Slim Wireless mouse', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3952095808383233, lift=3.3157376522123534)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.01786547563495767, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.3748251748251748, lift=3.1464759079756277), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.3748251748251748, lift=3.144716133977879)]),
#  RelationRecord(items=frozenset({'Premium Nylon USB Cable', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.010065995600293315, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.39425587467362927, lift=3.309587227744327), OrderedStatistic(items_base=frozenset({'Premium Nylon USB Cable', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.39425587467362927, lift=3.3077362281762372)]),
#  RelationRecord(items=frozenset({'SanDisk Extreme Pro 128GB card', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.0038664089060729285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Extreme Pro 128GB card'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.4113475177304965, lift=3.45306329797156), OrderedStatistic(items_base=frozenset({'SanDisk Extreme Pro 128GB card', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4113475177304965, lift=3.4511320545163184)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'Dust-Off Compressed Gas 2 pack', '0'}), support=0.020465302313179123, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack', '0'}), confidence=0.4165535956580733, lift=3.4967658021638264), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', '0'}), items_add=frozenset({'Dust-Off Compressed Gas 2 pack'}), confidence=0.4165535956580733, lift=3.4948101165921464)]),
# ...
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.003933071128591427, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'HP 61 ink'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.3430232558139535, lift=3.94003970939136), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Nylon Braided Lightning to USB cable', '0'}), confidence=0.2006802721088435, lift=4.2103563103563095), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.2822966507177033, lift=3.445672951518525), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'HP 61 ink', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3430232558139535, lift=3.94003970939136), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.2006802721088435, lift=4.2103563103563095), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.2822966507177033, lift=3.445672951518525)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit', '0'}), support=0.003066462235850943, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.2658959537572254, lift=4.10360617521825), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.27878787878787875, lift=3.40284537810982), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2658959537572254, lift=4.10360617521825), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.27878787878787875, lift=3.40284537810982)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.004599693353776415, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.3988439306358381, lift=4.581208119041507), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.23469387755102036, lift=4.776991665051366), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'SanDisk Ultra 64GB card', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3988439306358381, lift=4.581208119041507), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.23469387755102036, lift=4.776991665051366)]),
#  RelationRecord(items=frozenset({'USB 2.0 Printer cable', 'HP 61 ink', 'Screen Mom Screen Cleaner kit', '0'}), support=0.0036664222385174323, ordered_statistics=[OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'HP 61 ink'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.21317829457364343, lift=3.2900078157399437), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.30898876404494385, lift=3.771473107760946), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'HP 61 ink', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.21317829457364343, lift=3.2900078157399437), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.30898876404494385, lift=3.771473107760946)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), support=0.005466302246516899, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 61 ink', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.34024896265560167, lift=3.908173574882604), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.2789115646258503, lift=4.304477758181462), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.30827067669172936, lift=3.7627082351933536), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.34024896265560167, lift=3.908173574882604), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2789115646258503, lift=4.304477758181462), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.30827067669172936, lift=3.7627082351933536)]),
#  RelationRecord(items=frozenset({'HP 61 ink', 'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.003399773348443437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'HP 61 ink', 'Stylus Pen for iPad'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.3422818791946308, lift=3.931524096323627), OrderedStatistic(items_base=frozenset({'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.2698412698412698, lift=3.2936443359551575), OrderedStatistic(items_base=frozenset({'HP 61 ink', 'Stylus Pen for iPad', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3422818791946308, lift=3.931524096323627), OrderedStatistic(items_base=frozenset({'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.2698412698412698, lift=3.2936443359551575)]),
#  RelationRecord(items=frozenset({'USB 2.0 Printer cable', 'HP 61 ink', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.003999733351109926, ordered_statistics=[OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'HP 61 ink', '0'}), confidence=0.28985507246376807, lift=3.5379299772408337), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'HP 61 ink'}), confidence=0.28985507246376807, lift=3.5379299772408337)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.00433304446370242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'SanDisk Ultra 64GB card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.5118110236220472, lift=5.878772714666409), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.3110047846889952, lift=6.330234430284419), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Nylon Braided Lightning to USB cable', '0'}), confidence=0.22108843537414963, lift=4.638528138528138), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'SanDisk Ultra 64GB card', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.5118110236220472, lift=5.878772714666409), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.3110047846889952, lift=6.330234430284419), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.22108843537414963, lift=4.638528138528138)]),
#  RelationRecord(items=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), support=0.0041330577961469234, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.3502824858757062, lift=4.02342080445748), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.2966507177033493, lift=4.5782483706460315), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'Nylon Braided Lightning to USB cable', '0'}), confidence=0.2330827067669173, lift=4.890172984909827), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.3502824858757062, lift=4.02342080445748), OrderedStatistic(items_base=frozenset({'Nylon Braided Lightning to USB cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.2966507177033493, lift=4.5782483706460315), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'Nylon Braided Lightning to USB cable'}), confidence=0.2330827067669173, lift=4.890172984909827)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'SanDisk 128GB Ultra microSDXC card', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.0031997866808879407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'SanDisk 128GB Ultra microSDXC card'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.39999999999999997, lift=4.59448698315467), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'SanDisk 128GB Ultra microSDXC card'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.39344262295081966, lift=8.008185599572926), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'SanDisk 128GB Ultra microSDXC card', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.39999999999999997, lift=4.59448698315467), OrderedStatistic(items_base=frozenset({'SanDisk 128GB Ultra microSDXC card', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.39344262295081966, lift=8.008185599572926)]),
#  RelationRecord(items=frozenset({'VIVO Dual LCD Monitor Desk mount', 'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit', '0'}), support=0.0048663422438504095, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.4424242424242424, lift=5.08178105712562), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.24829931972789113, lift=3.8320350774054472), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.2744360902255639, lift=5.58591016210812), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.4424242424242424, lift=5.08178105712562), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.24829931972789113, lift=3.8320350774054472), OrderedStatistic(items_base=frozenset({'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.2744360902255639, lift=5.58591016210812)]),
#  RelationRecord(items=frozenset({'SanDisk Ultra 64GB card', 'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount', '0'}), support=0.0031997866808879407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Stylus Pen for iPad'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.4403669724770642, lift=5.0581508071427566), OrderedStatistic(items_base=frozenset({'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'SanDisk Ultra 64GB card', '0'}), confidence=0.25396825396825395, lift=5.169304990200512), OrderedStatistic(items_base=frozenset({'SanDisk Ultra 64GB card', 'Stylus Pen for iPad', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.4403669724770642, lift=5.0581508071427566), OrderedStatistic(items_base=frozenset({'Stylus Pen for iPad', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'SanDisk Ultra 64GB card'}), confidence=0.25396825396825395, lift=5.169304990200512)]),
#  RelationRecord(items=frozenset({'USB 2.0 Printer cable', 'VIVO Dual LCD Monitor Desk mount', 'Screen Mom Screen Cleaner kit', '0'}), support=0.0031997866808879407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'Screen Mom Screen Cleaner kit'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount', '0'}), confidence=0.2696629213483146, lift=3.097406954935733), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'VIVO Dual LCD Monitor Desk mount'}), items_add=frozenset({'Screen Mom Screen Cleaner kit', '0'}), confidence=0.23188405797101447, lift=3.578696248583527), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'Screen Mom Screen Cleaner kit', '0'}), items_add=frozenset({'VIVO Dual LCD Monitor Desk mount'}), confidence=0.2696629213483146, lift=3.097406954935733), OrderedStatistic(items_base=frozenset({'USB 2.0 Printer cable', 'VIVO Dual LCD Monitor Desk mount', '0'}), items_add=frozenset({'Screen Mom Screen Cleaner kit'}), confidence=0.23188405797101447, lift=3.578696248583527)])]

# %%
# Turning list into a new dataframe
df = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in result:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set, Items))                                   
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift']= Lift

# %%
# Showing new dataframe
df
# Out:
#                                                  Items  \
# 0    {Dust-Off Compressed Gas 2 pack, 10ft iPHone C...
# 1    {10ft iPHone Charger Cable 2 Pack, Screen Mom ...
# 2    {VIVO Dual LCD Monitor Desk mount, 10ft iPHone...
# 3    {3A USB Type C Cable 3 pack 6FT, Dust-Off Comp...
# 4          {HP 61 ink, 3A USB Type C Cable 3 pack 6FT}
# ..                                                 ...
# 827  {SanDisk Ultra 64GB card, Stylus Pen for iPad,...
# 828  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 829  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 830  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 831  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
#
#                                             Antecedent  \
# 0                   {10ft iPHone Charger Cable 2 Pack}
# 1                   {10ft iPHone Charger Cable 2 Pack}
# 2                   {10ft iPHone Charger Cable 2 Pack}
# 3                     {3A USB Type C Cable 3 pack 6FT}
# 4                     {3A USB Type C Cable 3 pack 6FT}
# ..                                                 ...
# 827  {Stylus Pen for iPad, VIVO Dual LCD Monitor De...
# 828  {USB 2.0 Printer cable, Screen Mom Screen Clea...
# 829  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 830  {USB 2.0 Printer cable, Screen Mom Screen Clea...
# 831  {USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
#
#                                 Consequent   Support  Confidence      Lift
# 0         {Dust-Off Compressed Gas 2 pack}  0.011533    0.456464  3.829654
# 1          {Screen Mom Screen Cleaner kit}  0.007599    0.300792  4.642154
# 2       {VIVO Dual LCD Monitor Desk mount}  0.007133    0.282322  3.242811
# 3         {Dust-Off Compressed Gas 2 pack}  0.008533    0.401254  3.366449
# 4                              {HP 61 ink}  0.005333    0.250784  3.061030
# ..                                     ...       ...         ...       ...
# 827              {SanDisk Ultra 64GB card}  0.003200    0.253968  5.169305
# 828  {VIVO Dual LCD Monitor Desk mount, 0}  0.003200    0.269663  3.097407
# 829     {Screen Mom Screen Cleaner kit, 0}  0.003200    0.231884  3.578696
# 830     {VIVO Dual LCD Monitor Desk mount}  0.003200    0.269663  3.097407
# 831        {Screen Mom Screen Cleaner kit}  0.003200    0.231884  3.578696
#
# [832 rows x 6 columns]

# %% [markdown]
# Now we have a table of every transaction, the antecedent and consequent, and the values for support, confidence, and lift.

# %%
# Showing the top rules by Support
df.sort_values(by ='Support', ascending = False, inplace = True)
df.head(10)
# Out:
#                                                  Items  \
# 38   {Dust-Off Compressed Gas 2 pack, Screen Mom Sc...
# 37   {Dust-Off Compressed Gas 2 pack, Screen Mom Sc...
# 162  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 161  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 160  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 159  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 36   {SanDisk Ultra 64GB card, Dust-Off Compressed ...
# 157  {SanDisk Ultra 64GB card, Dust-Off Compressed ...
# 158  {SanDisk Ultra 64GB card, Dust-Off Compressed ...
# 237  {SanDisk Ultra 64GB card, VIVO Dual LCD Monito...
#
#                               Antecedent  \
# 38       {Screen Mom Screen Cleaner kit}
# 37      {Dust-Off Compressed Gas 2 pack}
# 162   {Screen Mom Screen Cleaner kit, 0}
# 161  {Dust-Off Compressed Gas 2 pack, 0}
# 160      {Screen Mom Screen Cleaner kit}
# 159     {Dust-Off Compressed Gas 2 pack}
# 36             {SanDisk Ultra 64GB card}
# 157            {SanDisk Ultra 64GB card}
# 158         {SanDisk Ultra 64GB card, 0}
# 237            {SanDisk Ultra 64GB card}
#
#                                 Consequent   Support  Confidence      Lift
# 38        {Dust-Off Compressed Gas 2 pack}  0.023998    0.370370  3.107341
# 37         {Screen Mom Screen Cleaner kit}  0.023998    0.201342  3.107341
# 162       {Dust-Off Compressed Gas 2 pack}  0.023998    0.370370  3.107341
# 161        {Screen Mom Screen Cleaner kit}  0.023998    0.201455  3.109080
# 160    {Dust-Off Compressed Gas 2 pack, 0}  0.023998    0.370370  3.109080
# 159     {Screen Mom Screen Cleaner kit, 0}  0.023998    0.201342  3.107341
# 36        {Dust-Off Compressed Gas 2 pack}  0.020465    0.416554  3.494810
# 157    {Dust-Off Compressed Gas 2 pack, 0}  0.020465    0.416554  3.496766
# 158       {Dust-Off Compressed Gas 2 pack}  0.020465    0.416554  3.494810
# 237  {VIVO Dual LCD Monitor Desk mount, 0}  0.019599    0.398915  4.582019

# %%
# Showing the top rules by Confidence
df.sort_values(by ='Confidence', ascending = False, inplace = True)
df.head(10)
# Out:
#                                                  Items  \
# 328  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 589  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 587  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 453  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 260  {Dust-Off Compressed Gas 2 pack, 10ft iPHone C...
# 451  {Screen Mom Screen Cleaner kit, Dust-Off Compr...
# 288  {Dust-Off Compressed Gas 2 pack, Apple Pencil,...
# 508  {Premium Nylon USB Cable, Dust-Off Compressed ...
# 510  {Premium Nylon USB Cable, Dust-Off Compressed ...
# 368  {Nylon Braided Lightning to USB cable, SanDisk...
#
#                                             Antecedent  \
# 328  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 589  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 587  {Nylon Braided Lightning to USB cable, FEIYOLD...
# 453  {Screen Mom Screen Cleaner kit, 10ft iPHone Ch...
# 260  {10ft iPHone Charger Cable 2 Pack, Screen Mom ...
# 451  {10ft iPHone Charger Cable 2 Pack, Screen Mom ...
# 288            {Apple Pencil, Premium Nylon USB Cable}
# 508            {Apple Pencil, Premium Nylon USB Cable}
# 510         {Premium Nylon USB Cable, Apple Pencil, 0}
# 368  {Nylon Braided Lightning to USB cable, SanDisk...
#
#                               Consequent   Support  Confidence      Lift
# 328     {Dust-Off Compressed Gas 2 pack}  0.003266    0.576471  4.836485
# 589     {Dust-Off Compressed Gas 2 pack}  0.003266    0.576471  4.836485
# 587  {Dust-Off Compressed Gas 2 pack, 0}  0.003266    0.576471  4.839192
# 453     {Dust-Off Compressed Gas 2 pack}  0.004266    0.561404  4.710075
# 260     {Dust-Off Compressed Gas 2 pack}  0.004266    0.561404  4.710075
# 451  {Dust-Off Compressed Gas 2 pack, 0}  0.004266    0.561404  4.712711
# 288     {Dust-Off Compressed Gas 2 pack}  0.003200    0.545455  4.576266
# 508  {Dust-Off Compressed Gas 2 pack, 0}  0.003200    0.545455  4.578827
# 510     {Dust-Off Compressed Gas 2 pack}  0.003200    0.545455  4.576266
# 368     {Dust-Off Compressed Gas 2 pack}  0.004600    0.543307  4.558249

# %%
# Showing the top rules by Lift
df.sort_values(by ='Lift', ascending = False, inplace = True)
df.head(10)
# Out:
#                                                  Items  \
# 103  {FEIYOLD Blue light Blocking Glasses, Anker 2-...
# 104  {FEIYOLD Blue light Blocking Glasses, Anker 2-...
# 8    {FEIYOLD Blue light Blocking Glasses, Anker 2-...
# 817  {SanDisk Ultra 64GB card, SanDisk 128GB Ultra ...
# 815  {SanDisk Ultra 64GB card, SanDisk 128GB Ultra ...
# 442  {SanDisk Ultra 64GB card, VIVO Dual LCD Monito...
# 694  {SanDisk Ultra 64GB card, SanDisk 128GB Ultra ...
# 380  {SanDisk Ultra 64GB card, Dust-Off Compressed ...
# 692  {SanDisk Ultra 64GB card, SanDisk 128GB Ultra ...
# 472  {Nylon Braided Lightning to USB cable, Anker U...
#
#                                             Antecedent  \
# 103                     {Anker 2-in-1 USB Card Reader}
# 104                  {Anker 2-in-1 USB Card Reader, 0}
# 8                       {Anker 2-in-1 USB Card Reader}
# 817  {SanDisk 128GB Ultra microSDXC card, VIVO Dual...
# 815  {VIVO Dual LCD Monitor Desk mount, SanDisk 128...
# 442  {VIVO Dual LCD Monitor Desk mount, SanDisk 128...
# 694  {SanDisk 128GB Ultra microSDXC card, Dust-Off ...
# 380  {Dust-Off Compressed Gas 2 pack, SanDisk 128GB...
# 692  {Dust-Off Compressed Gas 2 pack, SanDisk 128GB...
# 472  {Nylon Braided Lightning to USB cable, VIVO Du...
#
#                                    Consequent   Support  Confidence      Lift
# 103  {FEIYOLD Blue light Blocking Glasses, 0}  0.004000    0.271493  8.260993
# 104     {FEIYOLD Blue light Blocking Glasses}  0.004000    0.271493  8.244271
# 8       {FEIYOLD Blue light Blocking Glasses}  0.004000    0.271493  8.244271
# 817                 {SanDisk Ultra 64GB card}  0.003200    0.393443  8.008186
# 815              {SanDisk Ultra 64GB card, 0}  0.003200    0.393443  8.008186
# 442                 {SanDisk Ultra 64GB card}  0.003200    0.393443  8.008186
# 694                 {SanDisk Ultra 64GB card}  0.003333    0.390625  7.950835
# 380                 {SanDisk Ultra 64GB card}  0.003333    0.390625  7.950835
# 692              {SanDisk Ultra 64GB card, 0}  0.003333    0.390625  7.950835
# 472          {Anker USB C to HDMI Adapter, 0}  0.003333    0.239234  6.995626

# %% [markdown]
# The top 3 rules are:
#
# Support: 	{Screen Mom Screen Cleaner kit, Dust-Off Compr...	{Dust-Off Compressed Gas 2 pack}	{Screen Mom Screen Cleaner kit, 0}	0.023998	0.201342	3.107341
#
# Confidence: {Nylon Braided Lightning to USB cable, FEIYOLD...	{Nylon Braided Lightning to USB cable, FEIYOLD...	{Dust-Off Compressed Gas 2 pack, 0}	0.003266	0.576471	4.839192
#
# Lift: {FEIYOLD Blue light Blocking Glasses, Anker 2-...	{Anker 2-in-1 USB Card Reader}	{FEIYOLD Blue light Blocking Glasses, 0}	0.004000	0.271493	8.260993

# %% [markdown]
# ## Part V: Data Summary and Implications

# %% [markdown]
# Support is a measure says how popular an itemset is, as measured by the proportion of transactions in which an itemset appears. For example, our top support is 0.023998, or appearing in about 2.4% of all transactions.
#
# Confidence is a measure that says how likely item Y is purchased when item X is purchased. This is measured by the proportion of transactions with item X, in which item Y also appears. Our top confidence is 0.576471, item y is purchased 57% of the time when item x is also purchased.
#
# Lift is a measure that says how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. A lift value greater than 1 means that item Y is likely to be bought if item X is bought, while a value less than 1 means that item Y is unlikely to be bought if item X is bought. Our top lift is 8.260993 meaning there is a very likely chance that item y will be bought along with item x.

# %% [markdown]
# The practical significance of this report shows that associations between item purchases can be found using market basket analysis and that a company could run this type of report and find significance between purchases. They could then use that data to make business decisions.

# %% [markdown]
# A course of action an organization could take from this report is finding items that generally get sold together, such as compressed air and screen cleaner kits, and offer a deal or discount when a customer purchases both items. From the report, we already know that it is fairly likely that a customer will purchase both items, but offering a discount when both are purchased would most likely convert even more customers to buy both products, rather than just choosing one.
